# %% [markdown]
# # Assignment 1.3 - Spatial Interpolation

# %% [markdown]
# ## Objective

# %% [markdown]
# ## Theory

# %% [markdown]
# ## Implementation

# %% [markdown]
# ## Results

# %% [markdown]
# ## Discussion

# %% [markdown]
# ## Conclusion
